# %%
# set path to dev directory
import sys
sys.path.append('/g/data/kj13/users/mgt562/med_diagnostics/MED-live-diagnostics/src')

# Import dev med_diagnostics package
import med_diagnostics

# %%
session = med_diagnostics.session.CreateModelDiagnosticsSession(model_type='CM2', 
                                                                model_path='/g/data/p73/archive/non-CMIP/ACCESS-CM2/by647')
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='dd05e71d-0187-46cb-8a31-e8722662516a'>
#   <div id="a5712f50-5411-4c95-a5bd-777eb15e7b5a" data-root-id="dd05e71d-0187-46cb-8a31-e8722662516a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
session.end_session()

# %%
import panel as pn

pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='0ce80ee3-5c2a-442f-a632-10ec0ff95372'>
#   <div id="b4b787fd-5ef9-4ed9-898b-72d1dcea5c51" data-root-id="0ce80ee3-5c2a-442f-a632-10ec0ff95372" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
# ...

# %%
column = pn.Column('# Column')
column.append(pn.Row(pn.widgets.Button(name='BTN1', margin=(10, 10, 0, 0)), pn.widgets.Button(name='BTN2', margin=(10, 10, 0, 0))) )
column
# Out:
# Column
#     [0] Markdown(str)
#     [1] Row
#         [0] Button(margin=(10, 10, 0, 0), name='BTN1')
#         [1] Button(margin=(10, 10, 0, 0), name='BTN2')
